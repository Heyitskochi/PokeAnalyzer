# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import random
import scipy.stats as at

# %%
file_to_load = "Resources/Pokemon_main_values.csv"
chart_to_load = "resources/chart.csv"
Pokemon_chart = pd.read_csv(chart_to_load)
Pokemon_data = pd.read_csv(file_to_load)
Pokemon_data
#Pokemon_chart
# Out:
#        #                   Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur    Grass    318  45      49       49       65
# 1      2                Ivysaur    Grass    405  60      62       63       80
# 2      3               Venusaur    Grass    525  80      82       83      100
# 3      3  VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4      4             Charmander     Fire    309  39      52       43       60
# ..   ...                    ...      ...    ...  ..     ...      ...      ...
# 795  719                Diancie     Rock    600  50     100      150      100
# 796  719    DiancieMega Diancie     Rock    700  50     160      110      160
# 797  720    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798  720     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799  721              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation
# 0         65     45           1
# 1         80     60           1
# 2        100     80           1
# 3        120     80           1
# 4         50     65           1
# ..       ...    ...         ...
# 795      150     50           6
# 796      110    110           6
# 797      130     70           6
# 798      130     80           6
# 799       90     70           6
#
# [800 rows x 11 columns]

# %%
Pokemon_data = Pokemon_data.set_index('#')

# %%
randomnum = random.randrange(1, 800)
random_pokemon= Pokemon_data.loc[randomnum]
random_pokemon
# Out:
# Name           Zubat
# Type 1        Poison
# Total            245
# HP                40
# Attack            45
# Defense           35
# Sp. Atk           30
# Sp. Def           40
# Speed             55
# Generation         1
# Name: 41, dtype: object

# %%
Pokemon_data.columns
# Out:
# Index(['Name', 'Type 1', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation'],
#       dtype='object')

# %%
filtered_df = Pokemon_data[['Name','Type 1','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']]
filtered_df.head()
# Out:
#                     Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# #
# 1              Bulbasaur  Grass  45      49       49       65       65     45
# 2                Ivysaur  Grass  60      62       63       80       80     60
# 3               Venusaur  Grass  80      82       83      100      100     80
# 3  VenusaurMega Venusaur  Grass  80     100      123      122      120     80
# 4             Charmander   Fire  39      52       43       60       50     65

# %%
Poke_df = filtered_df.loc[Pokemon_data["Type 1"] == random_pokemon[1]] 
Poke_df
# Out:
#           Name  Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# #
# 23       Ekans  Poison   35      60       44       40       54     55
# 24       Arbok  Poison   60      85       69       65       79     80
# 29    Nidoran♀  Poison   55      47       52       40       40     41
# 30    Nidorina  Poison   70      62       67       55       55     56
# 31   Nidoqueen  Poison   90      92       87       75       85     76
# 32    Nidoran♂  Poison   46      57       40       40       40     50
# 33    Nidorino  Poison   61      72       57       55       55     65
# 34    Nidoking  Poison   81     102       77       85       75     85
# 41       Zubat  Poison   40      45       35       30       40     55
# 42      Golbat  Poison   75      80       70       65       75     90
# 88      Grimer  Poison   80      80       50       40       50     25
# 89         Muk  Poison  105     105       75       65      100     50
# 109    Koffing  Poison   40      65       95       60       45     35
# 110    Weezing  Poison   65      90      120       85       70     60
# 169     Crobat  Poison   85      90       80       70       80    130
# 316     Gulpin  Poison   70      43       53       43       53     40
# 317     Swalot  Poison  100      73       83       73       83     55
# 336    Seviper  Poison   73     100       60      100       60     65
# 434     Stunky  Poison   63      63       47       41       41     74
# 435   Skuntank  Poison  103      93       67       71       61     84
# 451    Skorupi  Poison   40      50       90       30       55     65
# 452    Drapion  Poison   70      90      110       60       75     95
# 453   Croagunk  Poison   48      61       40       61       40     50
# 454  Toxicroak  Poison   83     106       65       86       65     85
# 568   Trubbish  Poison   50      50       62       40       62     65
# 569   Garbodor  Poison   80      95       82       60       82     75
# 690     Skrelp  Poison   50      60       60       60       60     30
# 691   Dragalge  Poison   65      75       90       97      123     44

# %%
sns.boxplot(data=Poke_df)
print(random_pokemon[1])
# Out:
# Poison

# %%
sns.boxplot(data=Pokemon_data)
# Out:
# <AxesSubplot:>

# %%
stats_Pokemon_data = Pokemon_data.drop(['Total','Generation'], axis =1)

# %%
sns.boxplot(data=stats_Pokemon_data)
yaxis='points'

# %%
txt = input("Champions Choose Your Pokemon")

print("Go",txt,"!")
# Out:
# Champions Choose Your PokemonCharmander
# Go Charmander !

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import random
import scipy.stats as at

# %%
file_to_load = "Resources/Pokemon_main_values.csv"
chart_to_load = "resources/chart.csv"
Pokemon_chart = pd.read_csv(chart_to_load)
Pokemon_data = pd.read_csv(file_to_load)
Pokemon_data
#Pokemon_chart
# Out:
#        #                   Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur    Grass    318  45      49       49       65
# 1      2                Ivysaur    Grass    405  60      62       63       80
# 2      3               Venusaur    Grass    525  80      82       83      100
# 3      3  VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4      4             Charmander     Fire    309  39      52       43       60
# ..   ...                    ...      ...    ...  ..     ...      ...      ...
# 795  719                Diancie     Rock    600  50     100      150      100
# 796  719    DiancieMega Diancie     Rock    700  50     160      110      160
# 797  720    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798  720     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799  721              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation
# 0         65     45           1
# 1         80     60           1
# 2        100     80           1
# 3        120     80           1
# 4         50     65           1
# ..       ...    ...         ...
# 795      150     50           6
# 796      110    110           6
# 797      130     70           6
# 798      130     80           6
# 799       90     70           6
#
# [800 rows x 11 columns]

# %%
Pokemon_data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation'],
#       dtype='object')

# %%
filtered_df = Pokemon_data[['Name','Type 1','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']]
filtered_df.head()
# Out:
#                     Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0              Bulbasaur  Grass  45      49       49       65       65     45
# 1                Ivysaur  Grass  60      62       63       80       80     60
# 2               Venusaur  Grass  80      82       83      100      100     80
# 3  VenusaurMega Venusaur  Grass  80     100      123      122      120     80
# 4             Charmander   Fire  39      52       43       60       50     65

# %%
Pokemon_data = Pokemon_data.set_index('Type 1')
